# %%
from __future__ import annotations

# %% [markdown]
# This is the main file for the implementation and validation of the DivideEtImpera
# algorithm.
#
#
# Written by Mattia Neroni in June 2020.
#
# Author contact: mattia.neroni@unipr.it

# %% [markdown]
# ---------------------------------------------------
# Imports from Python 3 standard library

# %%
from typing import Tuple, List, Optional, Union, Dict

# %% [markdown]
# Import from the DivideEtImpera package which imports the DEI class, the
# class for the solutions, and the class of the nodes.

# %%
from dei import DivideEtImpera, Solution, Node
from algorithms import Shuffler, RandomSearch, TwoOpt, Greedy, BiasedRandomised, SimulatedAnnealing, DaSilva

# %% [markdown]
# Problems

# %%
import n200w100_002 as problem1
import n250w300_003 as problem2
import n300w300_003 as problem3
import n200w100_001 as problem4
import n200w100_002 as problem5
import n200w100_003 as problem6
import n200w100_004 as problem7
import n200w100_005 as problem8
import n200w200_001 as problem9
import n200w200_002 as problem10
import n200w200_003 as problem11
import n200w200_004 as problem12
import n200w200_005 as problem13
import n200w300_001 as problem14
import n200w300_002 as problem15
import n200w300_003 as problem16
import n200w300_004 as problem17
import n200w300_005 as problem18
import n200w400_001 as problem19
import n200w400_002 as problem20
import n200w400_003 as problem21
import n200w400_004 as problem22
import n200w400_005 as problem23
import n200w500_001 as problem24
import n200w500_002 as problem25
import n200w500_003 as problem26
import n200w500_004 as problem27
import n200w500_005 as problem28
import n250w200_001 as problem29
import n250w200_002 as problem30
import n250w200_003 as problem31
import n250w200_004 as problem32
import n250w200_005 as problem33
import n250w300_001 as problem34
import n250w300_002 as problem35
import n250w300_003 as problem36
import n250w300_004 as problem37
import n250w300_005 as problem38
import n250w400_001 as problem39
import n250w400_002 as problem40
import n250w400_003 as problem41
import n250w400_004 as problem42
import n250w400_005 as problem43
import n250w500_001 as problem44
import n250w500_002 as problem45
import n250w500_003 as problem46
import n250w500_004 as problem47
import n250w500_005 as problem48
import n300w100_001 as problem49
import n300w100_002 as problem50
import n300w100_003 as problem51
import n300w100_004 as problem52
import n300w100_005 as problem53
import n300w200_001 as problem54
import n300w200_002 as problem55
import n300w200_003 as problem56
import n300w200_004 as problem57
import n300w200_005 as problem58
import n300w300_001 as problem59
import n300w300_002 as problem60
import n300w300_003 as problem61
import n300w300_004 as problem62
import n300w300_005 as problem63
import n300w400_001 as problem64
import n300w400_002 as problem65
import n300w400_003 as problem66
import n300w400_004 as problem67
import n300w400_005 as problem68
import n300w500_001 as problem69
import n300w500_002 as problem70
import n300w500_003 as problem71
import n300w500_004 as problem72
import n300w500_005 as problem73
import n350w100_001 as problem74
import n350w100_002 as problem75
import n350w100_003 as problem76
import n350w100_004 as problem77
import n350w100_005 as problem78
import n350w200_001 as problem79
import n350w200_002 as problem80
import n350w200_003 as problem81
import n350w200_004 as problem82
import n350w200_005 as problem83
import n350w300_001 as problem84
import n350w300_002 as problem85
import n350w300_003 as problem86
import n350w300_004 as problem87
import n350w300_005 as problem88
import n350w400_001 as problem89
import n350w400_002 as problem90
import n350w400_003 as problem91
import n350w400_004 as problem92
import n350w400_005 as problem93
import n350w500_001 as problem94
import n350w500_002 as problem95
import n350w500_003 as problem96
import n350w500_004 as problem97
import n350w500_005 as problem98
import n400w100_001 as problem99
import n400w100_002 as problem100
import n400w100_003 as problem101
import n400w100_004 as problem102
import n400w100_005 as problem103
import n400w200_001 as problem104
import n400w200_002 as problem105
import n400w200_003 as problem106
import n400w200_004 as problem107
import n400w200_005 as problem108
import n400w300_001 as problem109
import n400w300_002 as problem110
import n400w300_003 as problem111
import n400w300_004 as problem112
import n400w300_005 as problem113
import n400w400_001 as problem114
import n400w400_002 as problem115
import n400w400_003 as problem116
import n400w400_004 as problem117
import n400w400_005 as problem118
import n400w500_001 as problem119
import n400w500_002 as problem120
import n400w500_003 as problem121
import n400w500_004 as problem122
import n400w500_005 as problem123

# %%
problem_list = (
problem1,
problem2,
problem3,
problem4,
problem5,
problem6,
problem7,
problem8,
problem9,
problem10,
problem11,
problem12,
problem13,
problem14,
problem15,
problem16,
problem17,
problem18,
problem19,
problem20,
problem21,
problem22,
problem23,
problem24,
problem25,
problem26,
problem27,
problem28,
problem29,
problem30,
problem31,
problem32,
problem33,
problem34,
problem35,
problem36,
problem37,
problem38,
problem39,
problem40,
problem41,
problem42,
problem43,
problem44,
problem45,
problem46,
problem47,
problem48,
problem49,
problem50,
problem51,
problem52,
problem53,
problem54,
problem55,
problem56,
problem57,
problem58,
problem59,
problem60,
problem61,
problem62,
problem63,
problem64,
problem65,
problem66,
problem67,
problem68,
problem69,
problem70,
problem71,
problem72,
problem73,
problem74,
problem75,
problem76,
problem77,
problem78,
problem79,
problem80,
problem81,
problem82,
problem83,
problem84,
problem85,
problem86,
problem87,
problem88,
problem89,
problem90,
problem91,
problem92,
problem93,
problem94,
problem95,
problem96,
problem97,
problem98,
problem99,
problem100,
problem101,
problem102,
problem103,
problem104,
problem105,
problem106,
problem107,
problem108,
problem109,
problem110,
problem111,
problem112,
problem113,
problem114,
problem115,
problem116,
problem117,
problem118,
problem119,
problem120,
problem121,
problem122,
problem123
)

# %% [markdown]
# A function which evaluate the best solution found in literature for each benchmark problem

# %%
def evaluate_literature (solution : str,
                         distances : Dict[int, Dict[int, int]],
                         nodes : List[Node],
                         base_node : int = 1
                        ) -> Tuple[int,int]:
    """
    This function might be used to evaluate the solution to a benchmark found by
    the scientific community so far. The result might be compared to the one 
    found by the proposed algorithm to validate it.
    
    :param solution: the solution in a string as provided by DaSilva and Urrutia in 
                     their web page.
    :param distances: the matrix of distances between nodes
    :param node: the list of node (please refer to the Node class in algorithms package)
    :param base_node: the node where the tour starts and finishes; it represents the
                      depot.
    :return: the value and the delay of the solution
    
    """
    readytimes : Dict[int,int] = {n.id:n.readytime for n in nodes}
    duedates : Dict[int,int] = {n.id:n.duedate for n in nodes}
    
    tour : List[int] = [int(i) for i in solution.split(' ') if i != ""]
    tour.remove (base_node)
    
    current_node, value, delay = base_node, 0, 0
    for node in tour:
        value = max(readytimes.get(node), value + distances[current_node][node])
        delay += max(0, value - duedates.get(node)) 
        current_node = node
    value += distances[current_node][base_node]
    
    return value, delay

# %% [markdown]
# --------------------------------------------------
# <h6> Test the Shuffler </h6>

# %%
for problem in problem_list:

        NODES : List[Node] = [Node(int(n['num']),int(n['x']),int(n['y']),int(n['readytime']),int(n['duedate'])) for n in problem.problem]
        
        DEI = DivideEtImpera(
                algorithm = Shuffler(),
                nodes = NODES,
                p = 30,
                max_split = 10,
                base_node_id = 1,
                goback = True
            )
        solution : Solution = DEI.exe()
        
        value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
        
        print(problem.__name__,
              " - Tested Algorithm -> cost : ", solution.value, ", delay : ", solution.delay,
              " | Literature -> cost : ", value_literature, ", delay : ", delay_literature
             )
# Out:
# n200w100_002  - Tested Algorithm -> cost :  11771 , delay :  228912  | Literature -> cost :  10704 , delay :  2
# n250w300_003  - Tested Algorithm -> cost :  15093 , delay :  264931  | Literature -> cost :  13882 , delay :  1
# n300w300_003  - Tested Algorithm -> cost :  17538 , delay :  307074  | Literature -> cost :  15653 , delay :  3
# n200w100_001  - Tested Algorithm -> cost :  11452 , delay :  199333  | Literature -> cost :  10386 , delay :  6
# n200w100_002  - Tested Algorithm -> cost :  12005 , delay :  235371  | Literature -> cost :  10704 , delay :  2
# n200w100_003  - Tested Algorithm -> cost :  11435 , delay :  198706  | Literature -> cost :  10309 , delay :  0
# n200w100_004  - Tested Algorithm -> cost :  12061 , delay :  206217  | Literature -> cost :  10543 , delay :  7
# n200w100_005  - Tested Algorithm -> cost :  12263 , delay :  201193  | Literature -> cost :  10961 , delay :  3
# ...

# %% [markdown]
# <h6> Test the RandomSearch </h6>

# %%
for problem in problem_list:

        NODES : List[Node] = [Node(int(n['num']),int(n['x']),int(n['y']),int(n['readytime']),int(n['duedate'])) for n in problem.problem]
        
        DEI = DivideEtImpera(
                algorithm = RandomSearch(iter=1000),
                nodes = NODES,
                p = 30,
                max_split = 10,
                base_node_id = 1,
                goback = True
            )
        solution : Solution = DEI.exe()

        value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
        
        print(problem.__name__,
              " - Tested Algorithm -> cost : ", solution.value, ", delay : ", solution.delay,
              " | Literature -> cost : ", value_literature, ", delay : ", delay_literature
             )

# %% [markdown]
# <h6> Test the 2-OPT </h6>

# %%
for problem in problem_list:

        NODES : List[Node] = [Node(int(n['num']),int(n['x']),int(n['y']),int(n['readytime']),int(n['duedate'])) for n in problem.problem]
        
        DEI = DivideEtImpera(
                algorithm = TwoOpt(iter=1000),
                nodes = NODES,
                p = 30,
                max_split = 10,
                base_node_id = 1,
                goback = True
            )
        solution : Solution = DEI.exe()

        value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
        
        print(problem.__name__,
              " - Tested Algorithm -> cost : ", solution.value, ", delay : ", solution.delay,
              " | Literature -> cost : ", value_literature, ", delay : ", delay_literature
             )

# %% [markdown]
# <h6> Test the 2-OPT with deep search </h6>

# %%
for problem in problem_list:

        NODES : List[Node] = [Node(int(n['num']),int(n['x']),int(n['y']),int(n['readytime']),int(n['duedate'])) for n in problem.problem]
        
        DEI = DivideEtImpera(
                algorithm = TwoOpt(iter=300, deep=True),
                nodes = NODES,
                p = 30,
                max_split = 10,
                base_node_id = 1,
                goback = True
            )
        solution : Solution = DEI.exe()

        value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
        
        print(problem.__name__,
              " - Tested Algorithm -> cost : ", solution.value, ", delay : ", solution.delay,
              " | Literature -> cost : ", value_literature, ", delay : ", delay_literature
             )

# %% [markdown]
# <h6> Test the Greedy algorithm </h6>

# %%
for problem in problem_list:

        NODES : List[Node] = [Node(int(n['num']),int(n['x']),int(n['y']),int(n['readytime']),int(n['duedate'])) for n in problem.problem]
        
        DEI = DivideEtImpera(
                algorithm = Greedy(),
                nodes = NODES,
                p = 30,
                max_split = 10,
                base_node_id = 1,
                goback = True
            )
        solution : Solution = DEI.exe()

        value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
        
        print(problem.__name__,
              " - Tested Algorithm -> cost : ", solution.value, ", delay : ", solution.delay,
              " | Literature -> cost : ", value_literature, ", delay : ", delay_literature
             )

# %% [markdown]
# <h6> Test the Biased Randomised Algorithm (alpha = 0.9) </h6>

# %%
for problem in problem_list:

    NODES : List[Node] = [Node(int(n['num']),int(n['x']),int(n['y']),int(n['readytime']),int(n['duedate'])) for n in problem.problem]
        
    DEI = DivideEtImpera(
            algorithm = BiasedRandomised(alpha=0.9, starting_beta=0.1, delta_beta=0.05, iter=3000),
            nodes = NODES,
            p = len(NODES),
            max_split = 10,
            base_node_id = 1,
            goback = True
        )
    solution : Solution = DEI.exe()
    value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
        
    print(problem.__name__,
          " - Tested Algorithm -> cost : ", solution.value, ", delay : ", solution.delay,
          " | Literature -> cost : ", value_literature, ", delay : ", delay_literature
        )
# Out:
# n200w100_002  - Tested Algorithm -> cost :  10868 , delay :  14225  | Literature -> cost :  10704 , delay :  2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1118db94acc0> in <module>
#      11             goback = True
#      12         )
# ---> 13     solution : Solution = DEI.exe()
#      14     value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
#      15
#
# ~/Scaricati/DEI/dei.py in exe(self, tour)
#     411
#     412         else:
# --> 413             self._solve_tour (tour)
#     414
#     415
#
# ~/Scaricati/DEI/dei.py in _solve_tour(self, tour)
#     433         """
#     434
# --> 435         self.algorithm.exe(self.solution.value, tour, self.current_node, self.distances)
#     436         sol : Solution = self.algorithm.get_best_solution
#     437
#
# ...

# %% [markdown]
# <h6> Simulated Annealing </h6>

# %%
for problem in problem_list:

    NODES : List[Node] = [Node(int(n['num']),int(n['x']),int(n['y']),int(n['readytime']),int(n['duedate'])) for n in problem.problem]
        
    DEI = DivideEtImpera(
            algorithm = SimulatedAnnealing(era=1000,
                                           max_temperature=1.0,
                                           min_temperature=0.0,
                                           step=0.01,
                                           neighbour_prob=(0.5,0.5),
                                           greedy_start=True
                                          ),
            nodes = NODES,
            p = 30,
            max_split = 10,
            base_node_id = 1,
            goback = True
        )
    solution : Solution = DEI.exe()
    value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
        
    print(problem.__name__,
          " - Tested Algorithm -> cost : ", solution.value, ", delay : ", solution.delay,
          " | Literature -> cost : ", value_literature, ", delay : ", delay_literature
        )

# %% [markdown]
# <h6> Da Silva and Urrutia </h6>

# %%
for problem in problem_list:

    NODES : List[Node] = [Node(int(n['num']),int(n['x']),int(n['y']),int(n['readytime']),int(n['duedate'])) for n in problem.problem]
        
    DEI = DivideEtImpera(
            algorithm = DaSilva(iter=1, maxlevel=50),
            nodes = NODES,
            p = 30,
            max_split = 10,
            base_node_id = 1,
            goback = True
        )
    solution : Solution = DEI.exe()
    value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
        
    print(problem.__name__,
          " - Tested Algorithm -> cost : ", solution.value, ", delay : ", solution.delay,
          " | Literature -> cost : ", value_literature, ", delay : ", delay_literature
        )
# Out:
# n200w100_002  - Tested Algorithm -> cost :  11256 , delay :  90827  | Literature -> cost :  10704 , delay :  2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b4e26d98f756> in <module>
#      11             goback = True
#      12         )
# ---> 13     solution : Solution = DEI.exe()
#      14     value_literature, delay_literature = evaluate_literature (problem.s, DEI.distances, NODES, base_node = 1)
#      15
#
# ~/Scaricati/DEI/dei.py in exe(self, tour)
#     407             else:
#     408                 self.exe (first_part)
# --> 409                 self.exe (second_part)
#     410
#     411
#
# ~/Scaricati/DEI/dei.py in exe(self, tour)
#     406
#     407             else:
# --> 408                 self.exe (first_part)
#     409                 self.exe (second_part)
#     410
#
# ~/Scaricati/DEI/dei.py in exe(self, tour)
#     406
# ...
